# %% [markdown]
# <a href="https://colab.research.google.com/github/Misbahbaig332/Samsung-Innovation-Campus/blob/main/ex_0102.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Coding Exercise #0102

# %% [markdown]
# ### 1. Number:

# %% [markdown]
# #### 1.1. Operations with numbers:

# %%
1+1

# %%
2**3

# %%
8%5

# %%
8.0//5.0

# %% [markdown]
# ### 2. String:

# %% [markdown]
# #### 2.1. Basics:

# %%
# A quote within another quote.
print("He said, 'Python is very easy'")
print('He said, "Python is very easy"')

# %%
# Multi-line string.
my_string = """Hello !!!
my
name
is
Python."""
print(my_string)

# %% [markdown]
# #### 2.2. Operations with strings:

# %%
str1 = 'First string. '
str2 = 'Second string.'
print(str1 + str2)

# %%
str = 'Python. '
print(str*5)

# %% [markdown]
# #### 2.3. Indexing and slilcing strings:

# %%
str = 'Life is too short, You need Python!'
print(str[0])
print(str[-1])
print(str[0:4])
print(str[5:])

# %% [markdown]
# #### 2.4. Functions and methods for string objects:

# %%
x = 'Python'
print(len(x))

# %%
x.count('h')

# %%
x.upper()

# %%
x.lower()

# %%
x.find('o')

# %%
x.find('w')

# %%
x.index('o')

# %%
# 'w' is not found in x. This will result in an error.
x.index('w')

# %%
x = 'Life is too short, You need Python!'

# %%
x.split(' ')

# %%
y = x.split(' ')
a = ' '
print(a.join(y))

# %% [markdown]
# ### 3. Boolean:

# %% [markdown]
# #### 3.1. Operations with Booleans:

# %% [markdown]
# AND operator:

# %%
False and False

# %%
False and True

# %%
True and False

# %%
True and True

# %%
(3 > 2) and (5 < 4)

# %%
(3 > 2) and (5 > 4)

# %% [markdown]
# OR operator:

# %%
False or False

# %%
True or False

# %%
False or True

# %%
False or True

# %%
True or True

# %% [markdown]
# NOT operator:

# %%
not True

# %%
not False

# %%
not (4 > 2)

# %%
not (4 < 2)

# %% [markdown]
# #### 3.2. Implicit Boolean:

# %%
x = []
y = [1,2,3]

# %%
if x:
    print('Not empty.')
else:
    print('Empty!')

# %%
if y:
    print('Not empty.')
else:
    print('Empty!')
