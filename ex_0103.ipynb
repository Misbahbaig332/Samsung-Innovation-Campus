# %% [markdown]
# <a href="https://colab.research.google.com/github/Misbahbaig332/Samsung-Innovation-Campus/blob/main/ex_0103.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Coding Exercise #0103

# %% [markdown]
# ### 1. List:

# %% [markdown]
# #### 1.1. Creating lists:

# %%
x = [1, 3, True, False, 'Hello', [3,5,7]]
type(x)

# %%
# A range.
range(1,5)

# %%
# A range cast as list.
x = list(range(1,5))
x

# %%
list(range(1,10,2))

# %%
list(range(0,21,5))

# %% [markdown]
# #### 1.2. Indexing and slicing lists:

# %%
x = [1, 2, ['Life', 'is']]
x[1]

# %%
x[2]

# %%
x[2][1]

# %%
x = [1, 2, 3, ['a', 'b', 'c'], 4, 5]
x[2:5]

# %%
x[3][:2]

# %% [markdown]
# #### 1.3. Operations with lists:

# %%
a = [1, 2, 3]
b = [4, 5, 6]
a + b

# %%
x = [1, 2, 3]
x*3

# %% [markdown]
# #### 1.4. Changing list content:

# %%
x = [1, 2, 3]
x[1] = -1
x

# %%
x[1:3] = [3, 5, 7, 9, 11]
x

# %% [markdown]
# Let's carefully distinguish the following cases:

# %%
# Replace part of a list.
x = [1, 2, 3]
x[1:2] = [-1, -2, -3]
x

# %%
# List a particular element of the list.
x = [1, 2, 3]
x[1] = [-1, -2, -3]
x

# %% [markdown]
# #### 1.5. Deleting part of a list:

# %%
x = [1, 2, 3, 4, 5]
x[1:3] = []
x

# %%
x = [1, 2, 3, 4, 5]
del x[2]
x

# %% [markdown]
# #### 1.6. Functions and methods for list objects:

# %%
x = [2,4,6,8,10]
len(x)

# %%
x = [1, 2, 3]
x.append(4)
x.append([5,6])
x

# %%
x = [1, 2, 3, 4, 5]
x.reverse()
x

# %%
# The sort() method changes the list permanently.
x = [3, 1, 5, 2, 4]
x.sort()
x

# %%
x = [3, 1, 5, 2, 4]
x.sort(reverse=True)
x

# %%
# The function sorted() just returns a view without changing the list permanently.
x = [3, 1, 5, 2, 4]
sorted(x)

# %%
# We can verify that 'x' is the same as before.
x

# %% [markdown]
# ### 2. Tuple:

# %% [markdown]
# #### 2.1. Creating tuples:

# %%
x = (1, 3, True, False, 'Hello', [3,5,7])
type(x)

# %%
# A range cast as tuple.
x = tuple(range(1,5))
x

# %% [markdown]
# #### 2.2. Indexing and slicing tuples:

# %%
x = (1, 2, ('Life', 'is'))
x[2]

# %%
x[2][1]

# %%
x = (1, 2, 3, ['a', 'b', 'c'], 4, 5)
x[3][:2]

# %% [markdown]
# #### 2.3. Operations with tuples:

# %%
a = (1, 2, 3)
b = (4, 5, 6)
a + b

# %%
a * 3

# %% [markdown]
# ### 3. Dictionary:

# %% [markdown]
# #### 3.1. Creating dictionaries:

# %%
d = {'x':[1,2,3], 'y':[4,5,6]}

# %%
d['x']

# %%
d['y']

# %% [markdown]
# #### 3.2. Adding key-value pairs, deletion, update:

# %%
d = {}
d['name'] = 'John'
d['gender'] = 'Male'
d['age'] = 23
d

# %%
del d['age']
d

# %%
d['name'] = 'Andrew'
d

# %% [markdown]
# #### 3.3. Dictionary methods and operations:

# %%
d.keys()

# %%
d.values()

# %%
d.items()

# %%
d.clear()
d

# %%
d = {'name': 'John', 'gender': 'Male', 'age': 23}
d.get('wage', 0)

# %%
# Check whether 'name' is a key of d.
'name' in d

# %%
# Check whether 'wage' is a key of d.
'wage' in d

# %% [markdown]
# ### 4. Set:

# %% [markdown]
# #### 4.1. Creating a set:

# %%
b = set([1,2,3,3,3,3,4,5])
b

# %% [markdown]
# #### 4.2. Operations with sets:

# %%
s1 = set([1, 2, 3, 4, 5])
s2 = set([4, 5, 6, 7, 8])
s1 & s2

# %%
s1.intersection(s2)

# %%
s1 | s2

# %%
s1.union(s2)

# %%
s1 - s2

# %%
s1.difference(s2)

# %%
a = set([1, 2, 3, 4, 5])
a.add(6)
a

# %%
a.update([7, 8, 9])
a

# %%
a.remove(9)
a
